# %%
import torch
import matplotlib.pyplot as plt
from utils.plots import hdr_plot_style, plot_compare, plot_determ_comp
hdr_plot_style()

# %%
checkpoint = torch.load('./result/models/model_pecan_1129-1021.pth')
dataset = checkpoint['dataset']
ddpm = checkpoint['ddpm']
cond = checkpoint['cond']
config = checkpoint['config']
Loss = checkpoint['Loss']
config
# Out:
# {'n_steps': 500,
#  'input_dim': 96,
#  'hidden_dim': 512,
#  'nhead': 4,
#  'cond_dim': 212,
#  'epoch': 10000,
#  'batch_size': 1024,
#  'learning_rate': 0.0005,
#  'lr_decay': 0.9,
#  'ema_decay': 0.9,
#  'beta_start': 1e-06,
#  'beta_end': 0.02,
#  'loss_type': 'l2',
#  'num_class': 5}

# %%
plt.plot(Loss[10:])

# %%
for i in range(5):
    plot_compare(ddpm, dataset, cond, test_id=i)

# %%
for i in range(5):
    plot_determ_comp(ddpm, cond, i)
